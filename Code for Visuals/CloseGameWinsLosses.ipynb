# %%
import plotly.graph_objs as go
import plotly.figure_factory as ff

# Add table data
table_data1 = [['Team', 'Wins', 'Losses'],
              ['Utah', 48, 34],
              ['Phoenix', 21, 61],
              ['Los Angeles Clippers', 42, 40],
              ['Brooklyn', 28, 54],
              ['Denver', 46, 36],
              ['Philly',52, 30],
              ['Milwaukee', 44, 38],
              ['Los Angeles Lakers', 35, 47],
              ['Dallas',24, 58],
              ['Atlanta', 24, 58],
              ['New York', 29, 53],
              ['Portland', 49, 33],
              ['Memphis', 22, 60],
              ['Boston', 55, 27],
              ['Miami', 44, 38],
              ['San Antonio', 47, 35],
              ['Golden State', 58, 24],
              ['Charlotte', 36, 46],
              ['Indiana', 48, 34],
              ['Washington', 43, 39],
              ['New Orleans', 48, 34],
              ['Toronto', 59, 23],
              ['Chicago', 27, 55],
              ['Sacramento', 27, 55],
              ['Cleveland', 50, 32], 
              ['Oklaholma City', 48, 34],
              ['Detroit', 39, 43],
              ['Orlando', 25, 57],
              ['Minnesota', 47, 35],
              ['Houston', 65, 17]
             ]
# Initialize a fig with ff.create_table(table_data)
fig1 = ff.create_table(table_data1, height_constant=60)

# Add graph data
teams1 = ['Utah', 'Phoenix', 'Los Angeles Clippers', 'Brooklyn',
         'Denver', 'Philly', 'Milwaukee', 'Los Angeles Lakers', 
         'Dallas', 'Atlanta', 'New York', 'Portland', 'Memphis',
         'Boston', 'Miami', 'San Antonio', 'Golden State', 'Charlotte',
         'Indiana', 'Washington', 'New Orleans','Toronto', 'Chicago',
         'Sacaramento', 'Cleveland', 'Oklahoma City', 'Detroit', 'Orlando',
         'Minnesota', 'Houston']
GFPG1 = [48, 21, 42, 28, 46,
        52, 44, 35, 24, 24,
        29, 49, 22,55, 44, 
        47, 58, 36, 48, 43,
        48, 59, 27, 27, 50,
        48, 39, 25, 47, 65] # do GFPG as "Wins"
GAPG1 = [34, 61, 40, 54, 36,
        30, 38, 47, 58, 58,
        53, 33, 60, 27, 38,
        35, 24, 46, 34, 39,
        34, 23, 55, 55, 32,
        34, 43, 57, 35, 17] # do GAPG as "Losses"

fig1.add_trace(go.Bar(x=teams1, y=GFPG1, xaxis='x2', yaxis='y2',
                marker=dict(color='#0099ff'),
                name='# of Wins'))

fig1.add_trace(go.Bar(x=teams1, y=GAPG1, xaxis='x2', yaxis='y2',
                marker=dict(color='#404040'),
                name='# of Losses'))

fig1.update_layout(
    title_text = '2017-2018 NBA Season Team Standings',
    height = 800,
    margin = {'t':75, 'l':50},
    yaxis = {'domain': [0, .45]},
    xaxis2 = {'anchor': 'y2'},
    yaxis2 = {'domain': [.6, 1], 'anchor': 'x2', 'title': 'Goals'}
)

fig1.show()
# --------------------- Separate two seasons
# Add table data
table_data = [['Team', 'Wins', 'Losses'],
              ['Utah', 44, 16],
              ['Phoenix', 42, 18],
              ['Los Angeles Clippers', 43, 19],
              ['Brooklyn', 41, 20],
              ['Denver', 39, 21],
              ['Philly', 39, 21],
              ['Milwaukee', 37, 23],
              ['Los Angeles Lakers', 35, 25],
              ['Dallas',33, 26],
              ['Atlanta', 34, 27],
              ['New York', 34, 27],
              ['Portland', 32, 28],
              ['Memphis', 31, 28],
              ['Boston', 32, 29],
              ['Miami', 32, 29],
              ['San Antonio', 30, 29],
              ['Golden State', 31, 30],
              ['Charlotte', 29, 30],
              ['Indiana', 29, 31],
              ['Washington', 27, 33],
              ['New Orleans', 26, 34],
              ['Toronto', 25, 34],
              ['Chicago', 24, 35],
              ['Sacramento', 24, 36],
              ['Cleveland', 21, 39], 
              ['Oklaholma City', 20, 40],
              ['Detroit', 18, 42],
              ['Orlando', 18, 42],
              ['Minnesota', 17, 44],
              ['Houston', 15, 46]
             ]
# Initialize a fig with ff.create_table(table_data)
fig = ff.create_table(table_data, height_constant=60)

# Add graph data
teams = ['Utah', 'Phoenix', 'Los Angeles Clippers', 'Brooklyn',
         'Denver', 'Philly', 'Milwaukee', 'Los Angeles Lakers', 
         'Dallas', 'Atlanta', 'New York', 'Portland', 'Memphis',
         'Boston', 'Miami', 'San Antonio', 'Golden State', 'Charlotte',
         'Indiana', 'Washington', 'New Orleans','Toronto', 'Chicago',
         'Sacaramento', 'Cleveland', 'Oklahoma City', 'Detroit', 'Orlando',
         'Minnesota', 'Houston']
GFPG = [44, 42, 43, 41, 39,
        39, 37, 35, 33, 34,
        34, 32, 31,32, 32, 
        30, 31, 29, 29, 27,
        26, 25, 24, 24, 21,
        20,18, 18, 17, 15] # do GFPG as "Wins"
GAPG = [16, 18, 19, 20, 21,
        21, 23, 25, 26, 27,
        27, 28, 28, 29, 29,
        29, 30, 30, 31, 33,
        34, 34, 35, 36, 39,
        40, 42, 42, 44, 46] # do GAPG as "Losses"

fig.add_trace(go.Bar(x=teams, y=GFPG, xaxis='x2', yaxis='y2',
                marker=dict(color='#0099ff'),
                name='# of Wins'))

fig.add_trace(go.Bar(x=teams, y=GAPG, xaxis='x2', yaxis='y2',
                marker=dict(color='#404040'),
                name='# of Losses'))

fig.update_layout(
    title_text = '2020-2021 NBA Season Team Standings',
    height = 800,
    margin = {'t':75, 'l':50},
    yaxis = {'domain': [0, .45]},
    xaxis2 = {'anchor': 'y2'},
    yaxis2 = {'domain': [.6, 1], 'anchor': 'x2', 'title': 'Goals'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ebd7e90a-8503-4750-bcea-2a7b80574831" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ebd7e90a-8503-4750-bcea-2a7b80574831")) {
#                     Plotly.newPlot(
#                         'ebd7e90a-8503-4750-bcea-2a7b80574831',
# ...
